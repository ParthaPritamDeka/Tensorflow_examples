# %% [markdown]
# # TensorFlow Classification

# %% [markdown]
# ## Data
#
# https://archive.ics.uci.edu/ml/datasets/pima+indians+diabetes
#
# 1. Title: Pima Indians Diabetes Database
#
# 2. Sources:
#    (a) Original owners: National Institute of Diabetes and Digestive and
#                         Kidney Diseases
#    (b) Donor of database: Vincent Sigillito (vgs@aplcen.apl.jhu.edu)
#                           Research Center, RMI Group Leader
#                           Applied Physics Laboratory
#                           The Johns Hopkins University
#                           Johns Hopkins Road
#                           Laurel, MD 20707
#                           (301) 953-6231
#    (c) Date received: 9 May 1990
#
# 3. Past Usage:
#     1. Smith,~J.~W., Everhart,~J.~E., Dickson,~W.~C., Knowler,~W.~C., \&
#        Johannes,~R.~S. (1988). Using the ADAP learning algorithm to forecast
#        the onset of diabetes mellitus.  In {\it Proceedings of the Symposium
#        on Computer Applications and Medical Care} (pp. 261--265).  IEEE
#        Computer Society Press.
#
#        The diagnostic, binary-valued variable investigated is whether the
#        patient shows signs of diabetes according to World Health Organization
#        criteria (i.e., if the 2 hour post-load plasma glucose was at least
#        200 mg/dl at any survey  examination or if found during routine medical
#        care).   The population lives near Phoenix, Arizona, USA.
#
#        Results: Their ADAP algorithm makes a real-valued prediction between
#        0 and 1.  This was transformed into a binary decision using a cutoff of
#        0.448.  Using 576 training instances, the sensitivity and specificity
#        of their algorithm was 76% on the remaining 192 instances.
#
# 4. Relevant Information:
#       Several constraints were placed on the selection of these instances from
#       a larger database.  In particular, all patients here are females at
#       least 21 years old of Pima Indian heritage.  ADAP is an adaptive learning
#       routine that generates and executes digital analogs of perceptron-like
#       devices.  It is a unique algorithm; see the paper for details.
#
# 5. Number of Instances: 768
#
# 6. Number of Attributes: 8 plus class
#
#     7. For Each Attribute: (all numeric-valued)
#        1. Number of times pregnant
#        2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test
#        3. Diastolic blood pressure (mm Hg)
#        4. Triceps skin fold thickness (mm)
#        5. 2-Hour serum insulin (mu U/ml)
#        6. Body mass index (weight in kg/(height in m)^2)
#        7. Diabetes pedigree function
#        8. Age (years)
#        9. Class variable (0 or 1)
#
# 8. Missing Attribute Values: Yes
#
# 9. Class Distribution: (class value 1 is interpreted as "tested positive for
#    diabetes")
#
#    Class Value  Number of instances
#    0            500
#    1            268
#
# 10. Brief statistical analysis:
#
#         Attribute number:    Mean:   Standard Deviation:
#         1.                     3.8     3.4
#         2.                   120.9    32.0
#         3.                    69.1    19.4
#         4.                    20.5    16.0
#         5.                    79.8   115.2
#         6.                    32.0     7.9
#         7.                     0.5     0.3
#         8.                    33.2    11.8

# %%
import pandas as pd

# %%
diabetes = pd.read_csv('pima-indians-diabetes.csv')

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0                6               0.743719        0.590164  0.353535  0.000000
# 1                1               0.427136        0.540984  0.292929  0.000000
# 2                8               0.919598        0.524590  0.000000  0.000000
# 3                1               0.447236        0.540984  0.232323  0.111111
# 4                0               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
print (len(diabetes))
# Out:
# 768

# %% [markdown]
# ### Clean the Data

# %%
cols_to_norm = ['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
       'Insulin', 'BMI', 'Pedigree']

# %%
diabetes[cols_to_norm] = diabetes[cols_to_norm].apply(lambda x: (x - x.min()) / (x.max() - x.min()))

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %% [markdown]
# ### Feature Columns

# %%
diabetes.columns
# Out:
# Index(['Number_pregnant', 'Glucose_concentration', 'Blood_pressure', 'Triceps',
#        'Insulin', 'BMI', 'Pedigree', 'Age', 'Class', 'Group'],
#       dtype='object')

# %%
import tensorflow as tf

# %% [markdown]
# ### Continuous Features
#
# * Number of times pregnant
# * Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# * Diastolic blood pressure (mm Hg)
# * Triceps skin fold thickness (mm)
# * 2-Hour serum insulin (mu U/ml)
# * Body mass index (weight in kg/(height in m)^2)
# * Diabetes pedigree function

# %%
num_preg = tf.feature_column.numeric_column('Number_pregnant')
plasma_gluc = tf.feature_column.numeric_column('Glucose_concentration')
dias_press = tf.feature_column.numeric_column('Blood_pressure')
tricep = tf.feature_column.numeric_column('Triceps')
insulin = tf.feature_column.numeric_column('Insulin')
bmi = tf.feature_column.numeric_column('BMI')
diabetes_pedigree = tf.feature_column.numeric_column('Pedigree')
age = tf.feature_column.numeric_column('Age')

# %% [markdown]
# ### Categorical Features

# %% [markdown]
# If you know the set of all possible feature values of a column and there are only a few of them, you can use categorical_column_with_vocabulary_list. If you don't know the set of possible values in advance you can use categorical_column_with_hash_bucket

# %%
#assigned_group = tf.feature_column.categorical_column_with_vocabulary_list('Group',['A','B','C','D'])
# Alternative
assigned_group = tf.feature_column.categorical_column_with_hash_bucket('Group', hash_bucket_size=10,dtype=tf.string)

# %% [markdown]
# ### Converting Continuous to Categorical

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
diabetes['Age'].hist(bins=20)

# %%
age_buckets = tf.feature_column.bucketized_column(age, boundaries=[20,30,40,50,60,70,80])

# %% [markdown]
# ### Putting them together

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,assigned_group, age_buckets]

# %% [markdown]
# ### Train Test Split

# %%
diabetes.head()
# Out:
#    Number_pregnant  Glucose_concentration  Blood_pressure   Triceps   Insulin  \
# 0         0.352941               0.743719        0.590164  0.353535  0.000000
# 1         0.058824               0.427136        0.540984  0.292929  0.000000
# 2         0.470588               0.919598        0.524590  0.000000  0.000000
# 3         0.058824               0.447236        0.540984  0.232323  0.111111
# 4         0.000000               0.688442        0.327869  0.353535  0.198582
#
#         BMI  Pedigree  Age  Class Group
# 0  0.500745  0.234415   50      1     B
# 1  0.396423  0.116567   31      0     C
# 2  0.347243  0.253629   32      1     B
# 3  0.418778  0.038002   21      0     B
# 4  0.642325  0.943638   33      1     C

# %%
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 10 columns):
# Number_pregnant          768 non-null float64
# Glucose_concentration    768 non-null float64
# Blood_pressure           768 non-null float64
# Triceps                  768 non-null float64
# Insulin                  768 non-null float64
# BMI                      768 non-null float64
# Pedigree                 768 non-null float64
# Age                      768 non-null int64
# Class                    768 non-null int64
# Group                    768 non-null object
# dtypes: float64(7), int64(2), object(1)
# memory usage: 60.1+ KB

# %%
x_data = diabetes.drop('Class',axis=1)

# %%
labels = diabetes['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x_data,labels, stratify=labels,test_size=0.33, random_state=101)

# %% [markdown]
# ### Input Function

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=1000,shuffle=True)

# %% [markdown]
# ### Creating the Model

# %%
model = tf.estimator.LinearClassifier(feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\pdeka\AppData\Local\Temp\tmpw50kdbai
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\pdeka\\AppData\\Local\\Temp\\tmpw50kdbai', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000019E062E1470>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\pdeka\AppData\Local\Temp\tmp_wrzwrhc\model.ckpt.
# INFO:tensorflow:loss = 6.931472, step = 1
# INFO:tensorflow:global_step/sec: 283.397
# INFO:tensorflow:loss = 4.682441, step = 101 (0.355 sec)
# INFO:tensorflow:global_step/sec: 484.173
# INFO:tensorflow:loss = 6.4614367, step = 201 (0.209 sec)
# INFO:tensorflow:global_step/sec: 554.118
# INFO:tensorflow:loss = 6.2815266, step = 301 (0.180 sec)
# INFO:tensorflow:global_step/sec: 536.237
# INFO:tensorflow:loss = 5.7345257, step = 401 (0.185 sec)
# INFO:tensorflow:global_step/sec: 542.069
# INFO:tensorflow:loss = 4.392764, step = 501 (0.184 sec)
# INFO:tensorflow:global_step/sec: 536.237
# INFO:tensorflow:loss = 5.0112705, step = 601 (0.186 sec)
# INFO:tensorflow:global_step/sec: 539.14
# INFO:tensorflow:loss = 3.6814356, step = 701 (0.184 sec)
# INFO:tensorflow:global_step/sec: 481.836
# INFO:tensorflow:loss = 3.515285, step = 801 (0.211 sec)
# INFO:tensorflow:global_step/sec: 514.113
# INFO:tensorflow:loss = 5.1418223, step = 901 (0.191 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\pdeka\AppData\Local\Temp\tmp_wrzwrhc\model.ckpt.
# INFO:tensorflow:Loss for final step: 3.1111019.

# %%
# Useful link ofr your own data
# https://stackoverflow.com/questions/44664285/what-are-the-contraints-for-tensorflow-scope-names

# %% [markdown]
# ## Evaluation

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
results = model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-05-24-17:01:44
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\pdeka\AppData\Local\Temp\tmp_wrzwrhc\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-05-24-17:01:44
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.72440946, accuracy_baseline = 0.65748036, auc = 0.78474087, auc_precision_recall = 0.6212907, average_loss = 0.53350776, global_step = 1000, label/mean = 0.34251967, loss = 5.2119603, precision = 0.6103896, prediction/mean = 0.36736357, recall = 0.54022986

# %%
results
# Out:
# {'accuracy': 0.72440946,
#  'accuracy_baseline': 0.65748036,
#  'auc': 0.78474087,
#  'auc_precision_recall': 0.6212907,
#  'average_loss': 0.53350776,
#  'global_step': 1000,
#  'label/mean': 0.34251967,
#  'loss': 5.2119603,
#  'precision': 0.6103896,
#  'prediction/mean': 0.36736357,
#  'recall': 0.54022986}

# %% [markdown]
# ## Predictions

# %%
pred_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
# Predictions is a generator! 
predictions = model.predict(pred_input_func)

# %%
list(predictions)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\pdeka\AppData\Local\Temp\tmp_wrzwrhc\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# [{'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.51823175], dtype=float32),
#   'logits': array([0.0729593], dtype=float32),
#   'probabilities': array([0.48176828, 0.51823175], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6258628], dtype=float32),
#   'logits': array([0.5145086], dtype=float32),
#   'probabilities': array([0.3741372, 0.6258628], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.39052567], dtype=float32),
#   'logits': array([-0.44510305], dtype=float32),
#   'probabilities': array([0.6094743, 0.3905257], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.31189668], dtype=float32),
#   'logits': array([-0.79126704], dtype=float32),
#   'probabilities': array([0.68810326, 0.31189665], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14126097], dtype=float32),
#   'logits': array([-1.8048561], dtype=float32),
#   'probabilities': array([0.8587391 , 0.14126098], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.68560857], dtype=float32),
#   'logits': array([0.779668], dtype=float32),
#   'probabilities': array([0.31439146, 0.68560857], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.59024996], dtype=float32),
#   'logits': array([0.36499882], dtype=float32),
#   'probabilities': array([0.40975   , 0.59024996], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34680954], dtype=float32),
#   'logits': array([-0.6330931], dtype=float32),
#   'probabilities': array([0.6531905, 0.3468095], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23692371], dtype=float32),
#   'logits': array([-1.1696199], dtype=float32),
#   'probabilities': array([0.7630763 , 0.23692368], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23415452], dtype=float32),
#   'logits': array([-1.1849992], dtype=float32),
#   'probabilities': array([0.7658455 , 0.23415451], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1290883], dtype=float32),
#   'logits': array([-1.9090439], dtype=float32),
#   'probabilities': array([0.8709117, 0.1290883], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14771926], dtype=float32),
#   'logits': array([-1.7526025], dtype=float32),
#   'probabilities': array([0.85228074, 0.14771925], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.31000564], dtype=float32),
#   'logits': array([-0.80009294], dtype=float32),
#   'probabilities': array([0.6899944 , 0.31000566], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.57024026], dtype=float32),
#   'logits': array([0.2828313], dtype=float32),
#   'probabilities': array([0.4297598 , 0.57024026], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17182317], dtype=float32),
#   'logits': array([-1.5727608], dtype=float32),
#   'probabilities': array([0.8281768 , 0.17182317], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.32605395], dtype=float32),
#   'logits': array([-0.72608715], dtype=float32),
#   'probabilities': array([0.6739461 , 0.32605398], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.37262824], dtype=float32),
#   'logits': array([-0.52095795], dtype=float32),
#   'probabilities': array([0.6273718 , 0.37262827], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12995434], dtype=float32),
#   'logits': array([-1.9013625], dtype=float32),
#   'probabilities': array([0.87004566, 0.12995434], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3737721], dtype=float32),
#   'logits': array([-0.5160681], dtype=float32),
#   'probabilities': array([0.62622786, 0.37377205], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13370602], dtype=float32),
#   'logits': array([-1.8685808], dtype=float32),
#   'probabilities': array([0.86629397, 0.13370602], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21009716], dtype=float32),
#   'logits': array([-1.3243399], dtype=float32),
#   'probabilities': array([0.78990287, 0.21009716], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.29318956], dtype=float32),
#   'logits': array([-0.87994325], dtype=float32),
#   'probabilities': array([0.7068104 , 0.29318953], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.65404505], dtype=float32),
#   'logits': array([0.63686764], dtype=float32),
#   'probabilities': array([0.34595495, 0.65404505], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20829904], dtype=float32),
#   'logits': array([-1.335209], dtype=float32),
#   'probabilities': array([0.7917009 , 0.20829903], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17917058], dtype=float32),
#   'logits': array([-1.5219771], dtype=float32),
#   'probabilities': array([0.82082945, 0.17917056], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.76843935], dtype=float32),
#   'logits': array([1.1995198], dtype=float32),
#   'probabilities': array([0.23156068, 0.76843935], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17933308], dtype=float32),
#   'logits': array([-1.5208725], dtype=float32),
#   'probabilities': array([0.82066697, 0.17933309], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.30673203], dtype=float32),
#   'logits': array([-0.8154421], dtype=float32),
#   'probabilities': array([0.69326794, 0.30673203], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10268962], dtype=float32),
#   'logits': array([-2.1676908], dtype=float32),
#   'probabilities': array([0.8973103 , 0.10268962], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5783963], dtype=float32),
#   'logits': array([0.31619358], dtype=float32),
#   'probabilities': array([0.42160368, 0.5783963 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.938905], dtype=float32),
#   'logits': array([2.732283], dtype=float32),
#   'probabilities': array([0.06109507, 0.938905  ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4049806], dtype=float32),
#   'logits': array([-0.38475484], dtype=float32),
#   'probabilities': array([0.5950194, 0.4049806], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.30033848], dtype=float32),
#   'logits': array([-0.84568655], dtype=float32),
#   'probabilities': array([0.69966155, 0.3003385 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.57657623], dtype=float32),
#   'logits': array([0.30873418], dtype=float32),
#   'probabilities': array([0.4234237 , 0.57657623], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24499989], dtype=float32),
#   'logits': array([-1.1254601], dtype=float32),
#   'probabilities': array([0.75500005, 0.24499987], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38163415], dtype=float32),
#   'logits': array([-0.4826178], dtype=float32),
#   'probabilities': array([0.6183658 , 0.38163418], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5101346], dtype=float32),
#   'logits': array([0.04054379], dtype=float32),
#   'probabilities': array([0.48986545, 0.5101346 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6454339], dtype=float32),
#   'logits': array([0.5990282], dtype=float32),
#   'probabilities': array([0.354566 , 0.6454339], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.74897015], dtype=float32),
#   'logits': array([1.0931271], dtype=float32),
#   'probabilities': array([0.25102988, 0.74897015], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.32417428], dtype=float32),
#   'logits': array([-0.73465395], dtype=float32),
#   'probabilities': array([0.6758257 , 0.32417428], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17882685], dtype=float32),
#   'logits': array([-1.524316], dtype=float32),
#   'probabilities': array([0.82117313, 0.17882685], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5431043], dtype=float32),
#   'logits': array([0.1728462], dtype=float32),
#   'probabilities': array([0.4568957, 0.5431043], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15138216], dtype=float32),
#   'logits': array([-1.7238015], dtype=float32),
#   'probabilities': array([0.84861785, 0.15138215], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.52738863], dtype=float32),
#   'logits': array([0.10966444], dtype=float32),
#   'probabilities': array([0.4726113 , 0.52738863], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14082013], dtype=float32),
#   'logits': array([-1.8084949], dtype=float32),
#   'probabilities': array([0.8591799 , 0.14082015], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10018916], dtype=float32),
#   'logits': array([-2.1951246], dtype=float32),
#   'probabilities': array([0.89981085, 0.10018915], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6124323], dtype=float32),
#   'logits': array([0.45754778], dtype=float32),
#   'probabilities': array([0.38756773, 0.6124323 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1812628], dtype=float32),
#   'logits': array([-1.5078151], dtype=float32),
#   'probabilities': array([0.8187372 , 0.18126282], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20678864], dtype=float32),
#   'logits': array([-1.3443925], dtype=float32),
#   'probabilities': array([0.79321134, 0.20678863], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11447396], dtype=float32),
#   'logits': array([-2.0458345], dtype=float32),
#   'probabilities': array([0.88552606, 0.11447396], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16179629], dtype=float32),
#   'logits': array([-1.6449231], dtype=float32),
#   'probabilities': array([0.8382037 , 0.16179629], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24892674], dtype=float32),
#   'logits': array([-1.1043445], dtype=float32),
#   'probabilities': array([0.75107324, 0.24892674], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.24247093], dtype=float32),
#   'logits': array([-1.1391801], dtype=float32),
#   'probabilities': array([0.7575291 , 0.24247093], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3768953], dtype=float32),
#   'logits': array([-0.50274706], dtype=float32),
#   'probabilities': array([0.6231047, 0.3768953], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13445176], dtype=float32),
#   'logits': array([-1.8621576], dtype=float32),
#   'probabilities': array([0.86554825, 0.13445176], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.21077435], dtype=float32),
#   'logits': array([-1.3202642], dtype=float32),
#   'probabilities': array([0.7892257 , 0.21077435], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20203045], dtype=float32),
#   'logits': array([-1.3736521], dtype=float32),
#   'probabilities': array([0.7979696 , 0.20203044], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20692], dtype=float32),
#   'logits': array([-1.3435919], dtype=float32),
#   'probabilities': array([0.79308003, 0.20691998], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4935589], dtype=float32),
#   'logits': array([-0.02576566], dtype=float32),
#   'probabilities': array([0.50644106, 0.4935589 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15700239], dtype=float32),
#   'logits': array([-1.6807032], dtype=float32),
#   'probabilities': array([0.84299767, 0.15700239], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22925186], dtype=float32),
#   'logits': array([-1.2125405], dtype=float32),
#   'probabilities': array([0.77074814, 0.22925185], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.64067984], dtype=float32),
#   'logits': array([0.578316], dtype=float32),
#   'probabilities': array([0.3593202 , 0.64067984], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6316604], dtype=float32),
#   'logits': array([0.53934646], dtype=float32),
#   'probabilities': array([0.36833963, 0.6316604 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5147101], dtype=float32),
#   'logits': array([0.05885744], dtype=float32),
#   'probabilities': array([0.4852899, 0.5147101], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.33663654], dtype=float32),
#   'logits': array([-0.6783192], dtype=float32),
#   'probabilities': array([0.66336346, 0.33663654], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4903873], dtype=float32),
#   'logits': array([-0.03845572], dtype=float32),
#   'probabilities': array([0.50961274, 0.49038726], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17767045], dtype=float32),
#   'logits': array([-1.5322108], dtype=float32),
#   'probabilities': array([0.8223295 , 0.17767045], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19807927], dtype=float32),
#   'logits': array([-1.3983425], dtype=float32),
#   'probabilities': array([0.8019207 , 0.19807926], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15260601], dtype=float32),
#   'logits': array([-1.7143062], dtype=float32),
#   'probabilities': array([0.847394  , 0.15260601], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13107921], dtype=float32),
#   'logits': array([-1.8914502], dtype=float32),
#   'probabilities': array([0.86892074, 0.1310792 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.599203], dtype=float32),
#   'logits': array([0.4021454], dtype=float32),
#   'probabilities': array([0.400797, 0.599203], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23308235], dtype=float32),
#   'logits': array([-1.1909876], dtype=float32),
#   'probabilities': array([0.76691765, 0.23308237], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.42381805], dtype=float32),
#   'logits': array([-0.3071192], dtype=float32),
#   'probabilities': array([0.57618195, 0.42381808], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.56973994], dtype=float32),
#   'logits': array([0.28079033], dtype=float32),
#   'probabilities': array([0.43026   , 0.56973994], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2824106], dtype=float32),
#   'logits': array([-0.9325356], dtype=float32),
#   'probabilities': array([0.71758944, 0.2824106 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6435339], dtype=float32),
#   'logits': array([0.5907353], dtype=float32),
#   'probabilities': array([0.3564662, 0.6435339], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12192821], dtype=float32),
#   'logits': array([-1.974296], dtype=float32),
#   'probabilities': array([0.8780718, 0.1219282], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.59325904], dtype=float32),
#   'logits': array([0.37745452], dtype=float32),
#   'probabilities': array([0.406741  , 0.59325904], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12471846], dtype=float32),
#   'logits': array([-1.9484866], dtype=float32),
#   'probabilities': array([0.8752815 , 0.12471847], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5566638], dtype=float32),
#   'logits': array([0.22763312], dtype=float32),
#   'probabilities': array([0.4433362, 0.5566638], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3320922], dtype=float32),
#   'logits': array([-0.6987375], dtype=float32),
#   'probabilities': array([0.6679078, 0.3320922], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16601504], dtype=float32),
#   'logits': array([-1.6141369], dtype=float32),
#   'probabilities': array([0.833985  , 0.16601506], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.55701035], dtype=float32),
#   'logits': array([0.2290374], dtype=float32),
#   'probabilities': array([0.44298968, 0.55701035], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.58190286], dtype=float32),
#   'logits': array([0.33058977], dtype=float32),
#   'probabilities': array([0.4180971 , 0.58190286], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5556897], dtype=float32),
#   'logits': array([0.22368681], dtype=float32),
#   'probabilities': array([0.4443103, 0.5556897], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16512792], dtype=float32),
#   'logits': array([-1.620558], dtype=float32),
#   'probabilities': array([0.8348721 , 0.16512793], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3469739], dtype=float32),
#   'logits': array([-0.63236755], dtype=float32),
#   'probabilities': array([0.6530261, 0.3469739], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15225618], dtype=float32),
#   'logits': array([-1.7170141], dtype=float32),
#   'probabilities': array([0.8477438 , 0.15225616], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7068487], dtype=float32),
#   'logits': array([0.8801278], dtype=float32),
#   'probabilities': array([0.2931513, 0.7068487], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.82464975], dtype=float32),
#   'logits': array([1.5481733], dtype=float32),
#   'probabilities': array([0.17535026, 0.82464975], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.60523874], dtype=float32),
#   'logits': array([0.42734194], dtype=float32),
#   'probabilities': array([0.39476123, 0.60523874], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20490658], dtype=float32),
#   'logits': array([-1.3559055], dtype=float32),
#   'probabilities': array([0.7950935 , 0.20490658], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.43738115], dtype=float32),
#   'logits': array([-0.25179756], dtype=float32),
#   'probabilities': array([0.56261885, 0.4373811 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.37097684], dtype=float32),
#   'logits': array([-0.5280285], dtype=float32),
#   'probabilities': array([0.6290232 , 0.37097684], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.462737], dtype=float32),
#   'logits': array([-0.14932889], dtype=float32),
#   'probabilities': array([0.537263  , 0.46273696], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3487253], dtype=float32),
#   'logits': array([-0.6246471], dtype=float32),
#   'probabilities': array([0.65127474, 0.3487253 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.44568783], dtype=float32),
#   'logits': array([-0.21810931], dtype=float32),
#   'probabilities': array([0.55431217, 0.4456878 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15826738], dtype=float32),
#   'logits': array([-1.6711766], dtype=float32),
#   'probabilities': array([0.8417326 , 0.15826738], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5593861], dtype=float32),
#   'logits': array([0.2386707], dtype=float32),
#   'probabilities': array([0.44061399, 0.5593861 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.56397885], dtype=float32),
#   'logits': array([0.25732613], dtype=float32),
#   'probabilities': array([0.4360211 , 0.56397885], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23271531], dtype=float32),
#   'logits': array([-1.193042], dtype=float32),
#   'probabilities': array([0.76728463, 0.2327153 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1800779], dtype=float32),
#   'logits': array([-1.5158199], dtype=float32),
#   'probabilities': array([0.8199221 , 0.18007788], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17086992], dtype=float32),
#   'logits': array([-1.5794744], dtype=float32),
#   'probabilities': array([0.82913005, 0.17086993], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26796514], dtype=float32),
#   'logits': array([-1.0049713], dtype=float32),
#   'probabilities': array([0.73203486, 0.26796514], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38722783], dtype=float32),
#   'logits': array([-0.45897996], dtype=float32),
#   'probabilities': array([0.61277217, 0.38722783], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13767982], dtype=float32),
#   'logits': array([-1.8346958], dtype=float32),
#   'probabilities': array([0.86232024, 0.13767983], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.31812248], dtype=float32),
#   'logits': array([-0.76241356], dtype=float32),
#   'probabilities': array([0.68187755, 0.3181225 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22493257], dtype=float32),
#   'logits': array([-1.2371495], dtype=float32),
#   'probabilities': array([0.77506745, 0.22493257], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09876992], dtype=float32),
#   'logits': array([-2.2109675], dtype=float32),
#   'probabilities': array([0.90123004, 0.09876991], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12337068], dtype=float32),
#   'logits': array([-1.9608908], dtype=float32),
#   'probabilities': array([0.8766293 , 0.12337067], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7446877], dtype=float32),
#   'logits': array([1.0704774], dtype=float32),
#   'probabilities': array([0.2553123, 0.7446877], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17593737], dtype=float32),
#   'logits': array([-1.5441184], dtype=float32),
#   'probabilities': array([0.8240626 , 0.17593737], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13307221], dtype=float32),
#   'logits': array([-1.8740637], dtype=float32),
#   'probabilities': array([0.86692774, 0.13307221], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14073965], dtype=float32),
#   'logits': array([-1.8091602], dtype=float32),
#   'probabilities': array([0.8592603 , 0.14073965], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.49180013], dtype=float32),
#   'logits': array([-0.03280246], dtype=float32),
#   'probabilities': array([0.5081999, 0.4918001], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.46309343], dtype=float32),
#   'logits': array([-0.1478951], dtype=float32),
#   'probabilities': array([0.53690654, 0.4630935 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23322763], dtype=float32),
#   'logits': array([-1.190175], dtype=float32),
#   'probabilities': array([0.7667724 , 0.23322764], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.42939216], dtype=float32),
#   'logits': array([-0.2843315], dtype=float32),
#   'probabilities': array([0.57060784, 0.42939216], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18247749], dtype=float32),
#   'logits': array([-1.4996516], dtype=float32),
#   'probabilities': array([0.81752247, 0.18247749], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2165229], dtype=float32),
#   'logits': array([-1.2860456], dtype=float32),
#   'probabilities': array([0.7834771 , 0.21652292], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.48420078], dtype=float32),
#   'logits': array([-0.06321794], dtype=float32),
#   'probabilities': array([0.5157992 , 0.48420078], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.48486972], dtype=float32),
#   'logits': array([-0.06053954], dtype=float32),
#   'probabilities': array([0.5151303 , 0.48486975], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14232686], dtype=float32),
#   'logits': array([-1.7960968], dtype=float32),
#   'probabilities': array([0.85767317, 0.14232688], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.40811563], dtype=float32),
#   'logits': array([-0.37176073], dtype=float32),
#   'probabilities': array([0.5918844 , 0.40811566], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6909303], dtype=float32),
#   'logits': array([0.80447197], dtype=float32),
#   'probabilities': array([0.30906975, 0.6909303 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.54813117], dtype=float32),
#   'logits': array([0.19312263], dtype=float32),
#   'probabilities': array([0.45186886, 0.54813117], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.40325573], dtype=float32),
#   'logits': array([-0.39191765], dtype=float32),
#   'probabilities': array([0.59674424, 0.40325576], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5595068], dtype=float32),
#   'logits': array([0.23916054], dtype=float32),
#   'probabilities': array([0.44049326, 0.5595068 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22238633], dtype=float32),
#   'logits': array([-1.2518137], dtype=float32),
#   'probabilities': array([0.77761364, 0.22238635], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.19470142], dtype=float32),
#   'logits': array([-1.4197459], dtype=float32),
#   'probabilities': array([0.8052986 , 0.19470143], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13409816], dtype=float32),
#   'logits': array([-1.8651996], dtype=float32),
#   'probabilities': array([0.8659019 , 0.13409816], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.261721], dtype=float32),
#   'logits': array([-1.0370427], dtype=float32),
#   'probabilities': array([0.738279, 0.261721], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.48204497], dtype=float32),
#   'logits': array([-0.07185119], dtype=float32),
#   'probabilities': array([0.51795506, 0.4820449 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6881268], dtype=float32),
#   'logits': array([0.7913765], dtype=float32),
#   'probabilities': array([0.3118732, 0.6881268], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22464581], dtype=float32),
#   'logits': array([-1.2387949], dtype=float32),
#   'probabilities': array([0.77535415, 0.22464582], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16054471], dtype=float32),
#   'logits': array([-1.6541808], dtype=float32),
#   'probabilities': array([0.8394553 , 0.16054471], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.40597767], dtype=float32),
#   'logits': array([-0.3806187], dtype=float32),
#   'probabilities': array([0.59402233, 0.4059777 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2260522], dtype=float32),
#   'logits': array([-1.2307385], dtype=float32),
#   'probabilities': array([0.7739478 , 0.22605218], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14292985], dtype=float32),
#   'logits': array([-1.7911658], dtype=float32),
#   'probabilities': array([0.8570701 , 0.14292984], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17639825], dtype=float32),
#   'logits': array([-1.5409429], dtype=float32),
#   'probabilities': array([0.8236018 , 0.17639825], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12456305], dtype=float32),
#   'logits': array([-1.9499111], dtype=float32),
#   'probabilities': array([0.8754369 , 0.12456305], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.36822549], dtype=float32),
#   'logits': array([-0.5398372], dtype=float32),
#   'probabilities': array([0.63177454, 0.36822546], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7761845], dtype=float32),
#   'logits': array([1.2435683], dtype=float32),
#   'probabilities': array([0.22381547, 0.7761845 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7665983], dtype=float32),
#   'logits': array([1.1892017], dtype=float32),
#   'probabilities': array([0.23340175, 0.7665983 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.53857154], dtype=float32),
#   'logits': array([0.15459323], dtype=float32),
#   'probabilities': array([0.4614285 , 0.53857154], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4977756], dtype=float32),
#   'logits': array([-0.00889778], dtype=float32),
#   'probabilities': array([0.50222445, 0.49777558], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5617524], dtype=float32),
#   'logits': array([0.24827707], dtype=float32),
#   'probabilities': array([0.4382476, 0.5617524], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11304326], dtype=float32),
#   'logits': array([-2.0600257], dtype=float32),
#   'probabilities': array([0.88695675, 0.11304325], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5387863], dtype=float32),
#   'logits': array([0.1554575], dtype=float32),
#   'probabilities': array([0.46121368, 0.5387863 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.76339954], dtype=float32),
#   'logits': array([1.1714088], dtype=float32),
#   'probabilities': array([0.23660044, 0.76339954], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.41209745], dtype=float32),
#   'logits': array([-0.35530144], dtype=float32),
#   'probabilities': array([0.5879026 , 0.41209745], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26849326], dtype=float32),
#   'logits': array([-1.0022806], dtype=float32),
#   'probabilities': array([0.73150676, 0.26849326], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3654049], dtype=float32),
#   'logits': array([-0.55198103], dtype=float32),
#   'probabilities': array([0.63459504, 0.3654049 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5783238], dtype=float32),
#   'logits': array([0.31589603], dtype=float32),
#   'probabilities': array([0.42167628, 0.5783238 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.23388246], dtype=float32),
#   'logits': array([-1.186517], dtype=float32),
#   'probabilities': array([0.7661176 , 0.23388246], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6417621], dtype=float32),
#   'logits': array([0.5830201], dtype=float32),
#   'probabilities': array([0.35823798, 0.6417621 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4085028], dtype=float32),
#   'logits': array([-0.37015826], dtype=float32),
#   'probabilities': array([0.59149724, 0.4085028 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.41855845], dtype=float32),
#   'logits': array([-0.328694], dtype=float32),
#   'probabilities': array([0.5814416 , 0.41855845], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16147405], dtype=float32),
#   'logits': array([-1.6473011], dtype=float32),
#   'probabilities': array([0.83852595, 0.16147405], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18766363], dtype=float32),
#   'logits': array([-1.4652634], dtype=float32),
#   'probabilities': array([0.8123364 , 0.18766363], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18317686], dtype=float32),
#   'logits': array([-1.4949704], dtype=float32),
#   'probabilities': array([0.8168232 , 0.18317688], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4272336], dtype=float32),
#   'logits': array([-0.29314703], dtype=float32),
#   'probabilities': array([0.5727664, 0.4272336], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1467677], dtype=float32),
#   'logits': array([-1.7601807], dtype=float32),
#   'probabilities': array([0.8532323, 0.1467677], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.72205037], dtype=float32),
#   'logits': array([0.95465505], dtype=float32),
#   'probabilities': array([0.27794963, 0.72205037], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2013664], dtype=float32),
#   'logits': array([-1.3777761], dtype=float32),
#   'probabilities': array([0.79863364, 0.2013664 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.49569643], dtype=float32),
#   'logits': array([-0.01721478], dtype=float32),
#   'probabilities': array([0.5043036, 0.4956964], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15063977], dtype=float32),
#   'logits': array([-1.7295921], dtype=float32),
#   'probabilities': array([0.8493602 , 0.15063977], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6680951], dtype=float32),
#   'logits': array([0.6995821], dtype=float32),
#   'probabilities': array([0.3319049, 0.6680951], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.3194607], dtype=float32),
#   'logits': array([-0.75625134], dtype=float32),
#   'probabilities': array([0.6805393, 0.3194607], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1879794], dtype=float32),
#   'logits': array([-1.4631933], dtype=float32),
#   'probabilities': array([0.8120206, 0.1879794], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.35495162], dtype=float32),
#   'logits': array([-0.5973438], dtype=float32),
#   'probabilities': array([0.6450484 , 0.35495162], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.32780814], dtype=float32),
#   'logits': array([-0.7181153], dtype=float32),
#   'probabilities': array([0.6721919 , 0.32780814], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15706544], dtype=float32),
#   'logits': array([-1.6802268], dtype=float32),
#   'probabilities': array([0.84293455, 0.15706544], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7144831], dtype=float32),
#   'logits': array([0.917258], dtype=float32),
#   'probabilities': array([0.28551692, 0.7144831 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18352793], dtype=float32),
#   'logits': array([-1.4926258], dtype=float32),
#   'probabilities': array([0.81647205, 0.18352792], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.16140105], dtype=float32),
#   'logits': array([-1.6478403], dtype=float32),
#   'probabilities': array([0.83859897, 0.16140106], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27232316], dtype=float32),
#   'logits': array([-0.9828676], dtype=float32),
#   'probabilities': array([0.72767687, 0.27232316], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.43602926], dtype=float32),
#   'logits': array([-0.257293], dtype=float32),
#   'probabilities': array([0.56397074, 0.4360293 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26906225], dtype=float32),
#   'logits': array([-0.99938554], dtype=float32),
#   'probabilities': array([0.7309378 , 0.26906225], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11884518], dtype=float32),
#   'logits': array([-2.0034118], dtype=float32),
#   'probabilities': array([0.88115484, 0.11884518], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.82660663], dtype=float32),
#   'logits': array([1.561766], dtype=float32),
#   'probabilities': array([0.17339337, 0.82660663], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6650586], dtype=float32),
#   'logits': array([0.6859199], dtype=float32),
#   'probabilities': array([0.33494133, 0.6650586 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5226906], dtype=float32),
#   'logits': array([0.09082472], dtype=float32),
#   'probabilities': array([0.4773094, 0.5226906], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7350219], dtype=float32),
#   'logits': array([1.0202531], dtype=float32),
#   'probabilities': array([0.2649781, 0.7350219], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.11048844], dtype=float32),
#   'logits': array([-2.0857615], dtype=float32),
#   'probabilities': array([0.8895115 , 0.11048844], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.14357102], dtype=float32),
#   'logits': array([-1.7859416], dtype=float32),
#   'probabilities': array([0.856429  , 0.14357102], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.20696549], dtype=float32),
#   'logits': array([-1.3433146], dtype=float32),
#   'probabilities': array([0.7930345 , 0.20696549], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.32217708], dtype=float32),
#   'logits': array([-0.74378467], dtype=float32),
#   'probabilities': array([0.6778229 , 0.32217708], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.36323076], dtype=float32),
#   'logits': array([-0.56136906], dtype=float32),
#   'probabilities': array([0.63676924, 0.36323074], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5820865], dtype=float32),
#   'logits': array([0.3313446], dtype=float32),
#   'probabilities': array([0.4179135, 0.5820865], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5519507], dtype=float32),
#   'logits': array([0.20855534], dtype=float32),
#   'probabilities': array([0.44804937, 0.5519507 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.38491252], dtype=float32),
#   'logits': array([-0.46874833], dtype=float32),
#   'probabilities': array([0.61508745, 0.38491252], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.369087], dtype=float32),
#   'logits': array([-0.53613555], dtype=float32),
#   'probabilities': array([0.630913  , 0.36908704], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.34304553], dtype=float32),
#   'logits': array([-0.64975154], dtype=float32),
#   'probabilities': array([0.65695447, 0.34304553], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18008924], dtype=float32),
#   'logits': array([-1.515743], dtype=float32),
#   'probabilities': array([0.81991076, 0.18008924], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6425089], dtype=float32),
#   'logits': array([0.58627033], dtype=float32),
#   'probabilities': array([0.35749108, 0.6425089 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12850757], dtype=float32),
#   'logits': array([-1.9142194], dtype=float32),
#   'probabilities': array([0.87149245, 0.12850757], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.25282028], dtype=float32),
#   'logits': array([-1.0836269], dtype=float32),
#   'probabilities': array([0.74717975, 0.25282028], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.55696285], dtype=float32),
#   'logits': array([0.22884488], dtype=float32),
#   'probabilities': array([0.44303718, 0.55696285], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.357076], dtype=float32),
#   'logits': array([-0.5880779], dtype=float32),
#   'probabilities': array([0.6429241 , 0.35707602], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18307287], dtype=float32),
#   'logits': array([-1.4956657], dtype=float32),
#   'probabilities': array([0.81692713, 0.18307287], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27113375], dtype=float32),
#   'logits': array([-0.9888781], dtype=float32),
#   'probabilities': array([0.7288663 , 0.27113375], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.25606576], dtype=float32),
#   'logits': array([-1.0665183], dtype=float32),
#   'probabilities': array([0.7439342 , 0.25606576], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.13732736], dtype=float32),
#   'logits': array([-1.8376677], dtype=float32),
#   'probabilities': array([0.8626726 , 0.13732736], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.18241768], dtype=float32),
#   'logits': array([-1.5000527], dtype=float32),
#   'probabilities': array([0.8175823 , 0.18241765], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.57409793], dtype=float32),
#   'logits': array([0.29859054], dtype=float32),
#   'probabilities': array([0.4259021 , 0.57409793], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6702406], dtype=float32),
#   'logits': array([0.70927334], dtype=float32),
#   'probabilities': array([0.32975942, 0.6702406 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.623448], dtype=float32),
#   'logits': array([0.5042093], dtype=float32),
#   'probabilities': array([0.376552, 0.623448], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7020334], dtype=float32),
#   'logits': array([0.8569993], dtype=float32),
#   'probabilities': array([0.2979667, 0.7020334], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.45066354], dtype=float32),
#   'logits': array([-0.19798994], dtype=float32),
#   'probabilities': array([0.54933643, 0.4506636 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.29908824], dtype=float32),
#   'logits': array([-0.8516433], dtype=float32),
#   'probabilities': array([0.70091176, 0.29908827], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5140185], dtype=float32),
#   'logits': array([0.05608869], dtype=float32),
#   'probabilities': array([0.4859815, 0.5140185], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17205828], dtype=float32),
#   'logits': array([-1.5711095], dtype=float32),
#   'probabilities': array([0.8279417 , 0.17205828], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1449012], dtype=float32),
#   'logits': array([-1.7751648], dtype=float32),
#   'probabilities': array([0.8550988, 0.1449012], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17713016], dtype=float32),
#   'logits': array([-1.5359132], dtype=float32),
#   'probabilities': array([0.8228698 , 0.17713013], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5003559], dtype=float32),
#   'logits': array([0.0014236], dtype=float32),
#   'probabilities': array([0.4996441, 0.5003559], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.06084603], dtype=float32),
#   'logits': array([-2.7366328], dtype=float32),
#   'probabilities': array([0.93915397, 0.06084603], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2754364], dtype=float32),
#   'logits': array([-0.96721286], dtype=float32),
#   'probabilities': array([0.72456366, 0.2754364 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15824741], dtype=float32),
#   'logits': array([-1.6713264], dtype=float32),
#   'probabilities': array([0.8417525, 0.1582474], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.26359528], dtype=float32),
#   'logits': array([-1.027365], dtype=float32),
#   'probabilities': array([0.7364047 , 0.26359528], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22903374], dtype=float32),
#   'logits': array([-1.2137753], dtype=float32),
#   'probabilities': array([0.7709663 , 0.22903375], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.27204844], dtype=float32),
#   'logits': array([-0.98425436], dtype=float32),
#   'probabilities': array([0.7279516 , 0.27204844], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.76662326], dtype=float32),
#   'logits': array([1.1893417], dtype=float32),
#   'probabilities': array([0.23337668, 0.76662326], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17581256], dtype=float32),
#   'logits': array([-1.5449796], dtype=float32),
#   'probabilities': array([0.82418746, 0.17581256], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.12399369], dtype=float32),
#   'logits': array([-1.9551425], dtype=float32),
#   'probabilities': array([0.87600625, 0.1239937 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.58259237], dtype=float32),
#   'logits': array([0.33342445], dtype=float32),
#   'probabilities': array([0.41740763, 0.58259237], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4648209], dtype=float32),
#   'logits': array([-0.14094925], dtype=float32),
#   'probabilities': array([0.5351791, 0.4648209], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.8485492], dtype=float32),
#   'logits': array([1.723267], dtype=float32),
#   'probabilities': array([0.15145084, 0.8485492 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.62599075], dtype=float32),
#   'logits': array([0.51505506], dtype=float32),
#   'probabilities': array([0.37400925, 0.62599075], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1256367], dtype=float32),
#   'logits': array([-1.9401016], dtype=float32),
#   'probabilities': array([0.87436324, 0.12563668], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.6286882], dtype=float32),
#   'logits': array([0.5265933], dtype=float32),
#   'probabilities': array([0.3713118, 0.6286882], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.53018665], dtype=float32),
#   'logits': array([0.1208936], dtype=float32),
#   'probabilities': array([0.46981338, 0.53018665], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.76502705], dtype=float32),
#   'logits': array([1.1804408], dtype=float32),
#   'probabilities': array([0.23497295, 0.76502705], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.22724925], dtype=float32),
#   'logits': array([-1.2239091], dtype=float32),
#   'probabilities': array([0.77275074, 0.22724923], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17168517], dtype=float32),
#   'logits': array([-1.573731], dtype=float32),
#   'probabilities': array([0.82831484, 0.17168517], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5701471], dtype=float32),
#   'logits': array([0.2824514], dtype=float32),
#   'probabilities': array([0.4298529, 0.5701471], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1487285], dtype=float32),
#   'logits': array([-1.7446086], dtype=float32),
#   'probabilities': array([0.8512715 , 0.14872849], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.78411794], dtype=float32),
#   'logits': array([1.2898272], dtype=float32),
#   'probabilities': array([0.21588206, 0.78411794], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5199761], dtype=float32),
#   'logits': array([0.07994699], dtype=float32),
#   'probabilities': array([0.48002386, 0.5199761 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.17568442], dtype=float32),
#   'logits': array([-1.5458641], dtype=float32),
#   'probabilities': array([0.8243156 , 0.17568444], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.55085975], dtype=float32),
#   'logits': array([0.20414507], dtype=float32),
#   'probabilities': array([0.44914025, 0.55085975], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.47163317], dtype=float32),
#   'logits': array([-0.11358935], dtype=float32),
#   'probabilities': array([0.52836686, 0.47163317], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.10604862], dtype=float32),
#   'logits': array([-2.1317537], dtype=float32),
#   'probabilities': array([0.89395136, 0.10604862], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.5028393], dtype=float32),
#   'logits': array([0.01135743], dtype=float32),
#   'probabilities': array([0.49716067, 0.5028393 ], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.60878974], dtype=float32),
#   'logits': array([0.44222796], dtype=float32),
#   'probabilities': array([0.3912102 , 0.60878974], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.7376628], dtype=float32),
#   'logits': array([1.033856], dtype=float32),
#   'probabilities': array([0.2623372, 0.7376628], dtype=float32)},
#  {'class_ids': array([1], dtype=int64),
#   'classes': array([b'1'], dtype=object),
#   'logistic': array([0.81518555], dtype=float32),
#   'logits': array([1.4840635], dtype=float32),
#   'probabilities': array([0.18481442, 0.81518555], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.4306341], dtype=float32),
#   'logits': array([-0.27926433], dtype=float32),
#   'probabilities': array([0.56936586, 0.43063414], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.15654516], dtype=float32),
#   'logits': array([-1.6841618], dtype=float32),
#   'probabilities': array([0.84345484, 0.15654516], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.09023651], dtype=float32),
#   'logits': array([-2.3107505], dtype=float32),
#   'probabilities': array([0.9097635 , 0.09023652], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.1077687], dtype=float32),
#   'logits': array([-2.113738], dtype=float32),
#   'probabilities': array([0.8922313 , 0.10776871], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2476749], dtype=float32),
#   'logits': array([-1.1110516], dtype=float32),
#   'probabilities': array([0.75232506, 0.2476749 ], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.32006317], dtype=float32),
#   'logits': array([-0.7534814], dtype=float32),
#   'probabilities': array([0.67993677, 0.32006317], dtype=float32)},
#  {'class_ids': array([0], dtype=int64),
#   'classes': array([b'0'], dtype=object),
#   'logistic': array([0.2585903], dtype=float32),
#   'logits': array([-1.0533082], dtype=float32),
#   'probabilities': array([0.74140966, 0.2585903 ], dtype=float32)}]

# %% [markdown]
# # DNN Classifier

# %%
#dnn_model = tf.estimator.DNNClassifier(hidden_units=[10,10,10],feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\pdeka\AppData\Local\Temp\tmp01befa4m
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\pdeka\\AppData\\Local\\Temp\\tmp01befa4m', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000019E08EC9B70>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
# UH OH! AN ERROR. Check out the video to see why and how to fix.
# https://github.com/tensorflow/tensorflow/blob/master/tensorflow/python/feature_column/feature_column.py
#dnn_model.train(input_fn=input_func,steps=1000)

# %%
embedded_group_column = tf.feature_column.embedding_column(assigned_group, dimension=4)

#embedded_group_column = tf.feature_column.categorical_column_with_hash_bucket(key='Group', hash_bucket_size=10, dtype=tf.string)

# %%
feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,embedded_group_column, age_buckets]

#feat_cols = [num_preg ,plasma_gluc,dias_press ,tricep ,insulin,bmi,diabetes_pedigree ,assigned_group, age_buckets]

# %%
input_func = tf.estimator.inputs.pandas_input_fn(x=X_train,y=y_train,batch_size=10,num_epochs=2000,shuffle=True)

# %%
dnn_model = tf.estimator.DNNClassifier(hidden_units=[2048, 1024, 512, 256],feature_columns=feat_cols,n_classes=2)
# Out:
# INFO:tensorflow:Using default config.
# WARNING:tensorflow:Using temporary folder as model directory: C:\Users\pdeka\AppData\Local\Temp\tmp8w3n_k4g
# INFO:tensorflow:Using config: {'_model_dir': 'C:\\Users\\pdeka\\AppData\\Local\\Temp\\tmp8w3n_k4g', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': None, '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x0000019E09CC5F98>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}

# %%
dnn_model.train(input_fn=input_func,steps=1000)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 1 into C:\Users\pdeka\AppData\Local\Temp\tmp8w3n_k4g\model.ckpt.
# INFO:tensorflow:loss = 6.9762697, step = 1
# INFO:tensorflow:global_step/sec: 36.0652
# INFO:tensorflow:loss = 5.8681674, step = 101 (2.774 sec)
# INFO:tensorflow:global_step/sec: 37.8351
# INFO:tensorflow:loss = 6.6328, step = 201 (2.643 sec)
# INFO:tensorflow:global_step/sec: 38.0662
# INFO:tensorflow:loss = 3.0362685, step = 301 (2.627 sec)
# INFO:tensorflow:global_step/sec: 36.6397
# INFO:tensorflow:loss = 3.3490164, step = 401 (2.729 sec)
# INFO:tensorflow:global_step/sec: 32.9479
# INFO:tensorflow:loss = 6.7280774, step = 501 (3.036 sec)
# INFO:tensorflow:global_step/sec: 30.7914
# INFO:tensorflow:loss = 4.7757683, step = 601 (3.248 sec)
# INFO:tensorflow:global_step/sec: 33.8999
# INFO:tensorflow:loss = 4.8887606, step = 701 (2.949 sec)
# INFO:tensorflow:global_step/sec: 35.3164
# INFO:tensorflow:loss = 3.327925, step = 801 (2.832 sec)
# INFO:tensorflow:global_step/sec: 34.7261
# INFO:tensorflow:loss = 1.5367184, step = 901 (2.881 sec)
# INFO:tensorflow:Saving checkpoints for 1000 into C:\Users\pdeka\AppData\Local\Temp\tmp8w3n_k4g\model.ckpt.
# INFO:tensorflow:Loss for final step: 5.969789.

# %%
eval_input_func = tf.estimator.inputs.pandas_input_fn(
      x=X_test,
      y=y_test,
      #batch_size=10,
      num_epochs=1,
      shuffle=False)

# %%
dnn_model.evaluate(eval_input_func)
# Out:
# INFO:tensorflow:Calling model_fn.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# WARNING:tensorflow:Trapezoidal rule is known to produce incorrect PR-AUCs; please switch to "careful_interpolation" instead.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-05-24-21:21:23
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from C:\Users\pdeka\AppData\Local\Temp\tmp8w3n_k4g\model.ckpt-1000
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-05-24-21:21:24
# INFO:tensorflow:Saving dict for global step 1000: accuracy = 0.68110234, accuracy_baseline = 0.6496063, auc = 0.77037793, auc_precision_recall = 0.69117343, average_loss = 0.5787124, global_step = 1000, label/mean = 0.3503937, loss = 73.496475, precision = 0.5327869, prediction/mean = 0.40858656, recall = 0.7303371
# {'accuracy': 0.68110234,
#  'accuracy_baseline': 0.6496063,
#  'auc': 0.77037793,
#  'auc_precision_recall': 0.69117343,
#  'average_loss': 0.5787124,
#  'global_step': 1000,
#  'label/mean': 0.3503937,
#  'loss': 73.496475,
#  'precision': 0.5327869,
#  'prediction/mean': 0.40858656,
#  'recall': 0.7303371}
